# %% [markdown]
# ## Import Libraries

# %%
try:
    import pandas as pd
    from sqlalchemy import create_engine
    print("Successfully loaded libraries")
    
except ModuleNotFoundException as me:
    print("Module not found: {}".format(me))
# Out:
# Successfully loaded libraries

# %%
# !pip install fastparquet

# %%
# !pip install pyarrow

# !pip install fastparquet

# %% [markdown]
# ## Read Data

# %%
try:
    data=pd.read_parquet('../data/yellow_tripdata_2022-01.parquet', engine='pyarrow')
    
    
except FileNotFoundError as fe:
    print("File not found: {}".format(fe))
    exit(1)

# %%
data.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2022-01-01 00:35:40   2022-01-01 00:53:29              2.0
# 1         1  2022-01-01 00:33:43   2022-01-01 00:42:07              1.0
# 2         2  2022-01-01 00:53:21   2022-01-01 01:02:19              1.0
# 3         2  2022-01-01 00:25:21   2022-01-01 00:35:23              1.0
# 4         2  2022-01-01 00:36:48   2022-01-01 01:14:20              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           3.80         1.0                  N           142           236
# 1           2.10         1.0                  N           236            42
# 2           0.97         1.0                  N           166           166
# 3           1.09         1.0                  N           114            68
# 4           4.30         1.0                  N            68           163
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
data.shape
# Out:
# (2463931, 19)

# %% [markdown]
# ## Insert Into Database

# %%
#generate sql alchemy engine connection
engine=create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
engine.connect()

# %%
#converting to ddl
pd.io.sql.get_schema(data,name='yellow_taxi_data',con=engine)
# Out:
# '\nCREATE TABLE yellow_taxi_data (\n\t"VendorID" BIGINT, \n\ttpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE, \n\ttpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE, \n\tpassenger_count FLOAT(53), \n\ttrip_distance FLOAT(53), \n\t"RatecodeID" FLOAT(53), \n\tstore_and_fwd_flag TEXT, \n\t"PULocationID" BIGINT, \n\t"DOLocationID" BIGINT, \n\tpayment_type BIGINT, \n\tfare_amount FLOAT(53), \n\textra FLOAT(53), \n\tmta_tax FLOAT(53), \n\ttip_amount FLOAT(53), \n\ttolls_amount FLOAT(53), \n\timprovement_surcharge FLOAT(53), \n\ttotal_amount FLOAT(53), \n\tcongestion_surcharge FLOAT(53), \n\tairport_fee FLOAT(53)\n)\n\n'

# %%
data[:1000]
# Out:
#      VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0           1  2022-01-01 00:35:40   2022-01-01 00:53:29              2.0
# 1           1  2022-01-01 00:33:43   2022-01-01 00:42:07              1.0
# 2           2  2022-01-01 00:53:21   2022-01-01 01:02:19              1.0
# 3           2  2022-01-01 00:25:21   2022-01-01 00:35:23              1.0
# 4           2  2022-01-01 00:36:48   2022-01-01 01:14:20              1.0
# ..        ...                  ...                   ...              ...
# 995         2  2022-01-01 00:15:15   2022-01-01 00:19:08              2.0
# 996         2  2022-01-01 00:32:25   2022-01-01 00:44:22              3.0
# 997         2  2022-01-01 00:53:58   2022-01-01 00:57:04              2.0
# 998         2  2022-01-01 00:21:20   2022-01-01 00:32:00              1.0
# 999         2  2022-01-01 00:34:54   2022-01-01 00:43:45              1.0
#
#      trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# ...

# %%
#insert data into our postgresql database

# %time data[:900000].to_sql(name='yellow_taxi_data',con=engine, if_exists='replace',index=False)
# Out:
# CPU times: total: 1min 30s
# Wall time: 4min 4s
# 1000

# %%
#create query to fetch dataframe the database
query='''

SELECT * FROM yellow_taxi_data
LIMIT 20;
''' 

pd.read_sql(query, con=engine)
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0          1  2022-01-01 00:35:40   2022-01-01 00:53:29              2.0
# 1          1  2022-01-01 00:33:43   2022-01-01 00:42:07              1.0
# 2          2  2022-01-01 00:53:21   2022-01-01 01:02:19              1.0
# 3          2  2022-01-01 00:25:21   2022-01-01 00:35:23              1.0
# 4          2  2022-01-01 00:36:48   2022-01-01 01:14:20              1.0
# 5          1  2022-01-01 00:40:15   2022-01-01 01:09:48              1.0
# 6          2  2022-01-01 00:20:50   2022-01-01 00:34:58              1.0
# 7          2  2022-01-01 00:13:04   2022-01-01 00:22:45              1.0
# 8          2  2022-01-01 00:30:02   2022-01-01 00:44:49              1.0
# 9          2  2022-01-01 00:48:52   2022-01-01 00:53:28              1.0
# 10         2  2022-01-01 00:55:03   2022-01-01 01:04:25              1.0
# 11         2  2022-01-01 00:31:06   2022-01-01 00:34:14              3.0
# ...
